# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../transactions.csv')
df.punk_id = df.punk_id.astype(int)
df.drop('Unnamed: 0',axis=1,inplace=True)
df['Txn'] = df['Txn'].astype('datetime64')

# %%
df.head()
# Out:
#             Amount      From   To        Txn           Type  punk_id  \
# 0    250Ξ ($1.03M)  0x983ace  NaN 2021-05-10  Bid Withdrawn        0
# 1  250Ξ ($537,615)  0x983ace  NaN 2021-04-11            Bid        0
# 2  100Ξ ($160,973)  0xd7510a  NaN 2021-03-03  Bid Withdrawn        0
# 3  100Ξ ($188,897)  0xd7510a  NaN 2021-02-20            Bid        0
# 4    69Ξ ($25,532)  natealex  NaN 2020-09-16  Bid Withdrawn        0
#
#    amount_ethereum  amount_dollars
# 0            250.0       1030000.0
# 1            250.0        537615.0
# 2            100.0        160973.0
# 3            100.0        188897.0
# 4             69.0         25532.0

# %%
df.shape
# Out:
# (92823, 8)

# %%
punks = pd.read_csv('../Fase1_ETL/to_database/raw_punks.csv')
punks.drop('Unnamed: 0',axis=1,inplace=True)
punks.set_index('id',inplace=True)

# %%
punks.head()
# Out:
#      types  rarity   skin  total_traits                               traits  \
# id
# 0   Female    2023    Mid             3  Blonde Bob,Earring,Green Eye Shadow
# 1     Male    4352   Dark             2                         Mohawk,Smile
# 2   Female    8090  Light             1                            Wild Hair
# 3     Male    7896   Dark             3          Nerd Glasses,Pipe,Wild Hair
# 4     Male    7332    Mid             4    Big Shades,Earring,Goat,Wild Hair
#
#     total_hidden_traits hidden_traits
# id
# 0                     1       Earring
# 1                     0           NaN
# 2                     0           NaN
# 3                     0           NaN
# 4                     0           NaN

# %%
punks.shape
# Out:
# (10000, 7)

# %%
aggregated_df = df.merge(punks, how='left',left_on='punk_id',right_on='id',left_index=False, right_index=False, sort=False)
aggregated_df.head()
# Out:
#             Amount      From   To        Txn           Type  punk_id  \
# 0    250Ξ ($1.03M)  0x983ace  NaN 2021-05-10  Bid Withdrawn        0
# 1  250Ξ ($537,615)  0x983ace  NaN 2021-04-11            Bid        0
# 2  100Ξ ($160,973)  0xd7510a  NaN 2021-03-03  Bid Withdrawn        0
# 3  100Ξ ($188,897)  0xd7510a  NaN 2021-02-20            Bid        0
# 4    69Ξ ($25,532)  natealex  NaN 2020-09-16  Bid Withdrawn        0
#
#    amount_ethereum  amount_dollars   types  rarity skin  total_traits  \
# 0            250.0       1030000.0  Female    2023  Mid             3
# 1            250.0        537615.0  Female    2023  Mid             3
# 2            100.0        160973.0  Female    2023  Mid             3
# 3            100.0        188897.0  Female    2023  Mid             3
# 4             69.0         25532.0  Female    2023  Mid             3
#
#                                 traits  total_hidden_traits hidden_traits
# 0  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 1  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 2  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 3  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 4  Blonde Bob,Earring,Green Eye Shadow                    1       Earring

# %%
aggregated_df.Type.unique()
# Out:
# array(['Bid Withdrawn', 'Bid', 'Sold', 'Offered'], dtype=object)

# %%
offered = aggregated_df[aggregated_df['Type']=='Offered']
offered.head()
# Out:
#                Amount From   To        Txn     Type  punk_id  amount_ethereum  \
# 18     100Ξ ($18,303)  NaN  NaN 2018-09-12  Offered        0            100.0
# 19    200Ξ ($138,566)  NaN  NaN 2017-12-16  Offered        0            200.0
# 22     400Ξ ($96,376)  NaN  NaN 2017-07-07  Offered        0            400.0
# 35   79.50Ξ ($46,842)  NaN  NaN 2020-11-25  Offered        1             79.5
# 38  119.10Ξ ($65,980)  NaN  NaN 2020-11-22  Offered        1            119.1
#
#     amount_dollars   types  rarity  skin  total_traits  \
# 18         18303.0  Female    2023   Mid             3
# 19        138566.0  Female    2023   Mid             3
# 22         96376.0  Female    2023   Mid             3
# 35         46842.0    Male    4352  Dark             2
# 38         65980.0    Male    4352  Dark             2
#
#                                  traits  total_hidden_traits hidden_traits
# 18  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 19  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 22  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 35                         Mohawk,Smile                    0           NaN
# 38                         Mohawk,Smile                    0           NaN

# %%
df_agg = offered[['From','To','Txn','punk_id','Type','amount_ethereum','types','skin','rarity','traits']].reset_index(drop=True)

# %%
df_agg.head()
# Out:
#   From   To        Txn  punk_id     Type  amount_ethereum   types  skin  \
# 0  NaN  NaN 2018-09-12        0  Offered            100.0  Female   Mid
# 1  NaN  NaN 2017-12-16        0  Offered            200.0  Female   Mid
# 2  NaN  NaN 2017-07-07        0  Offered            400.0  Female   Mid
# 3  NaN  NaN 2020-11-25        1  Offered             79.5    Male  Dark
# 4  NaN  NaN 2020-11-22        1  Offered            119.1    Male  Dark
#
#    rarity                               traits
# 0    2023  Blonde Bob,Earring,Green Eye Shadow
# 1    2023  Blonde Bob,Earring,Green Eye Shadow
# 2    2023  Blonde Bob,Earring,Green Eye Shadow
# 3    4352                         Mohawk,Smile
# 4    4352                         Mohawk,Smile

# %%
df_agg.Type.unique()
# Out:
# array(['Offered'], dtype=object)

# %%
plt.subplots(figsize=(16,9))
df_agg.groupby('punk_id')['Type'].count().plot()
plt.title ('number of offers')
plt.show()

# %%
df_count_offered = df_agg.groupby('punk_id')['Type'].count().to_frame(name='total_offered')
df_mean_price = df_agg.groupby('punk_id')['amount_ethereum'].mean().to_frame(name='avg_offered_price')

# %%
df_counts = pd.concat([df_count_offered,df_mean_price,punks],axis=1)
df_counts = df_counts[['total_offered','avg_offered_price','types','rarity']]

# %%
df_counts.fillna(0,inplace=True)
df_counts.head(20)
# Out:
#     total_offered  avg_offered_price   types  rarity
# 0             3.0         233.333333  Female    2023
# 1            20.0         234.107000    Male    4352
# 2             0.0           0.000000  Female    8090
# 3             0.0           0.000000    Male    7896
# 4             0.0           0.000000    Male    7332
# 5             0.0           0.000000  Female    1960
# 6             0.0           0.000000    Male    7425
# 7             0.0           0.000000  Female     866
# 8             0.0           0.000000    Male    6530
# 9             0.0           0.000000    Male    1761
# 10            0.0           0.000000  Female    5668
# 11            0.0           0.000000  Female    2565
# 12            0.0           0.000000  Female    1201
# 13            0.0           0.000000  Female    1657
# 14            8.0         126.706250  Female     155
# 15            0.0           0.000000    Male    6494
# 16            0.0           0.000000    Male    8315
# 17            0.0           0.000000    Male    5303
# 18            0.0           0.000000    Male    4458
# 19            0.0           0.000000  Female    9915

# %%
df_counts.sort_values(by='rarity')[:100].plot(x='rarity',y= 'total_offered',kind='bar',figsize=(16,9))
plt.xlabel('top 100 rarest punks')

df_counts.sort_values(by='rarity')[:100].plot(x='rarity',y= 'avg_offered_price',kind='bar',figsize=(16,9))
plt.yticks(rotation=90)
plt.xlabel('top 100 rarest punks')
plt.ylabel('ETH')

plt.show()

# %%
# number of bids does not really affect if punk is rare
# avg ETH bid price not not really have an affect

# %%
sns.boxplot(x="types", y="amount_ethereum", data=df_agg, whis=np.inf)
sns.swarmplot(x="types", y="amount_ethereum", data=df_agg, color=".2")

# %%
df_agg.groupby('skin')['amount_ethereum'].mean()

# %%
 sns.stripplot(x=df_agg["amount_ethereum"])

# %%
sns.catplot(x='skin',y='amount_ethereum',data=df_agg,kind='box')
plt.show()
