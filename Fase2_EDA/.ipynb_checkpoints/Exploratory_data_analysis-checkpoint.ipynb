# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('raw_punks.csv')
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  int64
#  1   types                10000 non-null  object
#  2   rarity               10000 non-null  int64
#  3   skin                 10000 non-null  object
#  4   total_traits         10000 non-null  int64
#  5   traits               9992 non-null   object
#  6   total_hidden_traits  10000 non-null  int64
#  7   hidden_traits        629 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 625.1+ KB

# %%
df1[df1.traits.isnull()]
# Out:
#         id   types  rarity    skin  total_traits traits  total_hidden_traits  \
# 281    281    Male       7   Light             0    NaN                    0
# 510    510    Male       9     Mid             0    NaN                    0
# 641    641  Female       6   Light             0    NaN                    0
# 741    741    Male       5    Dark             0    NaN                    0
# 1050  1050  Female       8     Mid             0    NaN                    0
# 2204  2204  Female       4    Dark             0    NaN                    0
# 3307  3307    Male       3  Albino             0    NaN                    0
# 6487  6487  Female       2  Albino             0    NaN                    0
#
#      hidden_traits
# 281            NaN
# 510            NaN
# 641            NaN
# 741            NaN
# 1050           NaN
# 2204           NaN
# 3307           NaN
# 6487           NaN

# %%
df1.fillna('',inplace=True)

# %%
df1.head()
# Out:
#    id   types  rarity   skin  total_traits  \
# 0   0  Female    2023    Mid             3
# 1   1    Male    4352   Dark             2
# 2   2  Female    8090  Light             1
# 3   3    Male    7896   Dark             3
# 4   4    Male    7332    Mid             4
#
#                                 traits  total_hidden_traits hidden_traits
# 0  Blonde Bob,Earring,Green Eye Shadow                    1       Earring
# 1                         Mohawk,Smile                    0
# 2                            Wild Hair                    0
# 3          Nerd Glasses,Pipe,Wild Hair                    0
# 4    Big Shades,Earring,Goat,Wild Hair                    0

# %%
df1.rarity.sort_values()
# Out:
# 8348        1
# 6487        2
# 3307        3
# 2204        4
# 741         5
#         ...
# 1098     9996
# 2115     9997
# 2547     9998
# 419      9999
# 1025    10000
# Name: rarity, Length: 10000, dtype: int64

# %%
df_types = df1.groupby('types').count().sort_values(by='id',ascending=False)

# %%
df_types
# Out:
#           id  rarity  skin  total_traits  traits  total_hidden_traits  \
# types
# Male    6039    6039  6039          6039    6039                 6039
# Female  3840    3840  3840          3840    3840                 3840
# Zombie    88      88    88            88      88                   88
# Ape       24      24    24            24      24                   24
# Alien      9       9     9             9       9                    9
#
#         hidden_traits
# types
# Male             6039
# Female           3840
# Zombie             88
# Ape                24
# Alien               9

# %%
df_types.plot.pie(y='id',figsize=(6,6),explode=(0,0,0.1,1.1,2), 
             autopct = '%2.1f%%',legend=True,title='DISTRIBUTION OF PUNK TYPES')
plt.show()

# %%
df_skin = df1.groupby('skin').count().sort_values(by='id',ascending=False)
df_skin
# Out:
#           id  types  rarity  total_traits  traits  total_hidden_traits  \
# skin
# Mid     3031   3031    3031          3031    3031                 3031
# Light   3006   3006    3006          3006    3006                 3006
# Dark    2824   2824    2824          2824    2824                 2824
# Albino  1018   1018    1018          1018    1018                 1018
# Zombie    88     88      88            88      88                   88
# Ape       24     24      24            24      24                   24
# Alien      9      9       9             9       9                    9
#
#         hidden_traits
# skin
# Mid              3031
# Light            3006
# Dark             2824
# Albino           1018
# Zombie             88
# Ape                24
# Alien               9

# %%
df_skin.plot.pie(y='id',figsize=(6,6),explode=(0,0,0,0,0.1,1.1,2), 
             autopct = '%2.1f%%',legend=True,title='DISTRIBUTION OF PUNK SKIN')
plt.show()

# %%
# rank rarity and perform some visualization

df_raros = df1.iloc[df1.rarity.sort_values().index]
df_raros
# Out:
#         id   types  rarity    skin  total_traits  \
# 8348  8348    Male       1     Mid             7
# 6487  6487  Female       2  Albino             0
# 3307  3307    Male       3  Albino             0
# 2204  2204  Female       4    Dark             0
# 741    741    Male       5    Dark             0
# ...    ...     ...     ...     ...           ...
# 1098  1098    Male    9996    Dark             2
# 2115  2115  Female    9997   Light             2
# 2547  2547    Male    9998   Light             2
# 419    419  Female    9999     Mid             2
# 1025  1025    Male   10000     Mid             2
#
#                                                  traits  total_hidden_traits  \
# 8348  Big Beard,Buck Teeth,Cigarette,Classic Shades,...                    0
# 6487                                                                       0
# 3307                                                                       0
# 2204                                                                       0
# 741                                                                        0
# ...                                                 ...                  ...
# 1098                                    Bandana,Earring                    0
# 2115                                    Bandana,Earring                    0
# 2547                                    Bandana,Earring                    0
# 419                                     Bandana,Earring                    0
# 1025                                    Bandana,Earring                    0
#
#      hidden_traits
# 8348
# 6487
# 3307
# 2204
# 741
# ...            ...
# 1098
# 2115
# 2547
# 419
# 1025
#
# [10000 rows x 8 columns]

# %%
df_top_raros = df_raros.reset_index(drop=True)[['id','rarity','types','skin','total_traits','total_hidden_traits']][:50]
df_top_raros.head()
# Out:
#      id  rarity   types    skin  total_traits  total_hidden_traits
# 0  8348       1    Male     Mid             7                    0
# 1  6487       2  Female  Albino             0                    0
# 2  3307       3    Male  Albino             0                    0
# 3  2204       4  Female    Dark             0                    0
# 4   741       5    Male    Dark             0                    0

# %%
df_top_50_skin = df_top_raros.groupby('skin').count().sort_values(by='total_traits',ascending=False)
df_top_50_skin
# Out:
#         id  rarity  types  total_traits  total_hidden_traits
# skin
# Ape     21      21     21            21                   21
# Alien    9       9      9             9                    9
# Dark     7       7      7             7                    7
# Mid      7       7      7             7                    7
# Albino   3       3      3             3                    3
# Light    3       3      3             3                    3

# %%
df_top_50_skin.plot.pie(y='id',figsize=(6,6), 
             autopct = '%2.1f%%',legend=True,title='TOP 50 RARITY PUNKS BY SKIN')

plt.show()

# %%
df_top_50_types = df_top_raros.groupby('types').count().sort_values(by='total_traits',ascending=False)
df_top_50_types
# Out:
#         id  rarity  skin  total_traits  total_hidden_traits
# types
# Ape     21      21    21            21                   21
# Female  10      10    10            10                   10
# Male    10      10    10            10                   10
# Alien    9       9     9             9                    9

# %%
df_top_50_types.plot.pie(y='id',figsize=(6,6), 
             autopct = '%2.1f%%',legend=True,title='TOP 50 RARITY PUNKS BY TYPE')

plt.show()

# %%
# analysis en funcion de los traits
df1.traits
# Out:
# 0                   Blonde Bob,Earring,Green Eye Shadow
# 1                                          Mohawk,Smile
# 2                                             Wild Hair
# 3                           Nerd Glasses,Pipe,Wild Hair
# 4                     Big Shades,Earring,Goat,Wild Hair
#                              ...
# 9995               Purple Eye Shadow,Straight Hair Dark
# 9996                 Cigarette,Crazy Hair,Earring,Smile
# 9997                            Cap Forward,Front Beard
# 9998    Black Lipstick,Clown Eyes Green,Wild White Hair
# 9999                                Mohawk,Nerd Glasses
# Name: traits, Length: 10000, dtype: object

# %%
df_traits = df1.groupby('total_traits').count().sort_values(by='id',ascending=False)
df_traits
# Out:
#                 id  types  rarity  skin  traits  total_hidden_traits  \
# total_traits
# 3             4501   4501    4501  4501    4501                 4501
# 2             3560   3560    3560  3560    3560                 3560
# 4             1420   1420    1420  1420    1420                 1420
# 1              333    333     333   333     333                  333
# 5              166    166     166   166     166                  166
# 6               11     11      11    11      11                   11
# 0                8      8       8     8       8                    8
# 7                1      1       1     1       1                    1
#
#               hidden_traits
# total_traits
# 3                      4501
# 2                      3560
# 4                      1420
# 1                       333
# 5                       166
# 6                        11
# 0                         8
# 7                         1

# %%
df_traits.plot.pie(y='id',figsize=(6,6), 
             autopct = '%2.1f%%',explode=(0,0,0,0,0,0.1,1.1,2),legend=True,title='PUNKS BY TRAIT COUNT')

plt.show()

# %%
df_hidden_traits = df1.groupby('total_hidden_traits').count().sort_values(by='id',ascending=False)
df_hidden_traits
# Out:
#                        id  types  rarity  skin  total_traits  traits  \
# total_hidden_traits
# 0                    9371   9371    9371  9371          9371    9371
# 1                     623    623     623   623           623     623
# 2                       5      5       5     5             5       5
# 3                       1      1       1     1             1       1
#
#                      hidden_traits
# total_hidden_traits
# 0                             9371
# 1                              623
# 2                                5
# 3                                1

# %%
df_hidden_traits.plot.pie(y='id',figsize=(6,6), 
             autopct = '%2.1f%%',explode=(0,0,1.1,2),legend=True,title='PUNKS BY HIDDEN TRAIT COUNT')

plt.show()

# %%
# cuantos punks tienen 7 atributos?
df_top_raros[df_top_raros.total_traits == 7]
# Out:
#      id  rarity types skin  total_traits  total_hidden_traits
# 0  8348       1  Male  Mid             7                    0

# %%
# cuantos punks tienen 3 atributos ocultos?
df_top_raros[df_top_raros.total_hidden_traits == 3]
# Out:
#       id  rarity   types  skin  total_traits  total_hidden_traits
# 25  5949      26  Female  Dark             6                    3

# %%
df_hidden_traits_top = df_raros[:50].groupby('total_hidden_traits').count()

df_hidden_traits_top.plot.pie(y='id',figsize=(6,6), 
             autopct = '%2.1f%%',legend=True,title='TOP 50 RARITY PUNKS BY HIDDEN TRAIT COUNT')

plt.show()

# %%
df_raros.reset_index(drop=True)[['total_traits','total_hidden_traits']][:50].describe().round(2)
df_raros
# Out:
#         id   types  rarity    skin  total_traits  \
# 8348  8348    Male       1     Mid             7
# 6487  6487  Female       2  Albino             0
# 3307  3307    Male       3  Albino             0
# 2204  2204  Female       4    Dark             0
# 741    741    Male       5    Dark             0
# ...    ...     ...     ...     ...           ...
# 1098  1098    Male    9996    Dark             2
# 2115  2115  Female    9997   Light             2
# 2547  2547    Male    9998   Light             2
# 419    419  Female    9999     Mid             2
# 1025  1025    Male   10000     Mid             2
#
#                                                  traits  total_hidden_traits  \
# 8348  Big Beard,Buck Teeth,Cigarette,Classic Shades,...                    0
# 6487                                                                       0
# 3307                                                                       0
# 2204                                                                       0
# 741                                                                        0
# ...                                                 ...                  ...
# 1098                                    Bandana,Earring                    0
# 2115                                    Bandana,Earring                    0
# 2547                                    Bandana,Earring                    0
# 419                                     Bandana,Earring                    0
# 1025                                    Bandana,Earring                    0
#
#      hidden_traits
# 8348
# 6487
# 3307
# 2204
# 741
# ...            ...
# 1098
# 2115
# 2547
# 419
# 1025
#
# [10000 rows x 8 columns]

# %%
# analysis por el tipo de trait
df1.traits
# Out:
# 0                   Blonde Bob,Earring,Green Eye Shadow
# 1                                          Mohawk,Smile
# 2                                             Wild Hair
# 3                           Nerd Glasses,Pipe,Wild Hair
# 4                     Big Shades,Earring,Goat,Wild Hair
#                              ...
# 9995               Purple Eye Shadow,Straight Hair Dark
# 9996                 Cigarette,Crazy Hair,Earring,Smile
# 9997                            Cap Forward,Front Beard
# 9998    Black Lipstick,Clown Eyes Green,Wild White Hair
# 9999                                Mohawk,Nerd Glasses
# Name: traits, Length: 10000, dtype: object

# %%
#get traits 
traits ={}
for items in df1.traits.str.split(','):
    for elem in items:        
        if len(elem) ==0:
            #print(type(elem))
            continue            
        if elem in traits:
            #print('exists, add one')
            traits[elem] += 1
        else:
            #print('not exist, create set to one ')
            traits[elem] = 1

# %%
len(traits)
# Out:
# 89

# %%
traits.items()
# Out:
# dict_items([('Blonde Bob', 147), ('Earring', 2459), ('Green Eye Shadow', 271), ('Mohawk', 441), ('Smile', 238), ('Wild Hair', 447), ('Nerd Glasses', 572), ('Pipe', 317), ('Big Shades', 535), ('Goat', 295), ('Half Shaved', 147), ('Purple Eye Shadow', 262), ('Do-rag', 300), ('Clown Eyes Blue', 384), ('Spots', 123), ('Wild White Hair', 136), ('Luxurious Beard', 286), ('Messy Hair', 460), ('Big Beard', 146), ('Clown Nose', 212), ('Police Cap', 203), ('Blue Eye Shadow', 266), ('Black Lipstick', 617), ('Clown Eyes Green', 382), ('Straight Hair Dark', 148), ('Blonde Short', 129), ('Purple Lipstick', 655), ('Straight Hair Blonde', 144), ('Hot Lipstick', 696), ('Pilot Helmet', 54), ('Regular Shades', 527), ('Small Shades', 378), ('Stringy Hair', 463), ('Frown', 261), ('Eye Mask', 293), ('Muttonchops', 303), ('Bandana', 481), ('Horned Rim Glasses', 535), ('Crazy Hair', 414), ('Classic Shades', 502), ('Handlebars', 263), ('Mohawk Dark', 429), ('Dark Hair', 157), ('Peak Spike', 303), ('Cap', 351), ('Normal Beard Black', 289), ('VR', 332), ('Frumpy Hair', 442), ('Cigarette', 961), ('Normal Beard', 292), ('Red Mohawk', 147), ('Shaved Head', 300), ('Chinstrap', 282), ('Mole', 644), ('Knitted Cap', 419), ('Fedora', 186), ('Shadow Beard', 526), ('Straight Hair', 151), ('Hoodie', 259), ('Eye Patch', 461), ('Headband', 406), ('Cowboy Hat', 142), ('Tassle Hat', 178), ('3D Glasses', 286), ('Mustache', 288), ('Vape', 272), ('Choker', 48), ('Pink With Hat', 95), ('Welding Goggles', 86), ('Vampire Hair', 147), ('Mohawk Thin', 441), ('Tiara', 55), ('Front Beard Dark', 260), ('Cap Forward', 254), ('Gold Chain', 169), ('Purple Hair', 165), ('Beanie', 44), ('Clown Hair Green', 148), ('Pigtails', 94), ('Silver Chain', 156), ('Front Beard', 273), ('Rosy Cheeks', 128), ('Orange Side', 68), ('Wild Blonde', 144), ('Buck Teeth', 78), ('Top Hat', 115), ('Medical Mask', 174), ('Spots Teeth', 1), ('Medical Mask Teeth', 1)])

# %%
order_traits = dict(sorted(traits.items(),key= lambda x:x[1],reverse=True))

# %%
df_traits = pd.DataFrame(list(order_traits.items()),columns = ['trait','occurences'])

# %%
df_traits
# Out:
#                  trait  occurences
# 0              Earring        2459
# 1            Cigarette         961
# 2         Hot Lipstick         696
# 3      Purple Lipstick         655
# 4                 Mole         644
# ..                 ...         ...
# 84        Pilot Helmet          54
# 85              Choker          48
# 86              Beanie          44
# 87         Spots Teeth           1
# 88  Medical Mask Teeth           1
#
# [89 rows x 2 columns]

# %%
data_top = df_traits[:20]

# %%
data_top.head()
# Out:
#              trait  occurences
# 0          Earring        2459
# 1        Cigarette         961
# 2     Hot Lipstick         696
# 3  Purple Lipstick         655
# 4             Mole         644

# %%
sns.catplot(x='trait',y='occurences',data= data_top,kind='bar',height=5, aspect=10/5,color='lightblue')
plt.title('TOP 20 traits based on TOTAL occurences')
plt.xticks(rotation=90)
plt.show()

# %%
most_common_all = set(data_top.trait.unique())

# %%
def get_traits():
    traits ={}
    for items in df_raros[0:50].traits.str.split(','):
        for elem in items:        
            if len(elem) ==0:
                #print(type(elem))
                continue            
            if elem in traits:
                #print('exists, add one')
                traits[elem] += 1
            else:
                #print('not exist, create set to one ')
                traits[elem] = 1
    return traits

traits = get_traits()
len(traits)
# Out:
# 54

# %%
order_traits = dict(sorted(traits.items(),key= lambda x:x[1],reverse=True))
df_top_traits = pd.DataFrame(list(order_traits.items()),columns = ['trait','occurences']) [0:20]

sns.catplot(x='trait',y='occurences',data= df_top_traits,kind='bar',height=5, aspect=10/5,color='lightblue')
plt.title('TOP 20 traits based on top 50 rarity')
plt.xticks(rotation=90)
plt.show()

# %%
most_common_top = set(df_top_traits.trait.unique())

# %%
print(list(most_common_top -most_common_all))
# Out:
# ['Medical Mask', 'Top Hat', 'Clown Nose', 'Headband', 'Knitted Cap', 'Gold Chain', 'Cap', 'Do-rag', 'Pipe', 'Cowboy Hat', 'Cap Forward', 'Small Shades']

# %%
data_bottom = df_traits[-5:]
sns.catplot(x='trait',y='occurences',data= data_bottom,kind='bar',height=4, aspect=10/5,color='lightblue')
plt.title('BOTTOM 5 traits based on TOTAL occurences')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='types',y='total_traits',hue='total_hidden_traits',data= df1,kind='bar')

# %%
#get traits 
traits ={}
for items in df1.traits.str.split(','):
    for elem in items:        
        if len(elem) ==0:
            #print(type(elem))
            continue            
        if elem in traits:
            #print('exists, add one')
            traits[elem] += 1
        else:
            #print('not exist, create set to one ')
            traits[elem] = 1

# %%
len(traits)
# Out:
# 89

# %%
traits
# Out:
# {'Blonde Bob': 147,
#  'Earring': 2459,
#  'Green Eye Shadow': 271,
#  'Mohawk': 441,
#  'Smile': 238,
#  'Wild Hair': 447,
#  'Nerd Glasses': 572,
#  'Pipe': 317,
#  'Big Shades': 535,
#  'Goat': 295,
#  'Half Shaved': 147,
#  'Purple Eye Shadow': 262,
#  'Do-rag': 300,
#  'Clown Eyes Blue': 384,
#  'Spots': 123,
#  'Wild White Hair': 136,
#  'Luxurious Beard': 286,
#  'Messy Hair': 460,
#  'Big Beard': 146,
#  'Clown Nose': 212,
#  'Police Cap': 203,
#  'Blue Eye Shadow': 266,
#  'Black Lipstick': 617,
#  'Clown Eyes Green': 382,
#  'Straight Hair Dark': 148,
#  'Blonde Short': 129,
#  'Purple Lipstick': 655,
#  'Straight Hair Blonde': 144,
#  'Hot Lipstick': 696,
#  'Pilot Helmet': 54,
#  'Regular Shades': 527,
#  'Small Shades': 378,
#  'Stringy Hair': 463,
#  'Frown': 261,
#  'Eye Mask': 293,
#  'Muttonchops': 303,
#  'Bandana': 481,
#  'Horned Rim Glasses': 535,
#  'Crazy Hair': 414,
#  'Classic Shades': 502,
#  'Handlebars': 263,
#  'Mohawk Dark': 429,
#  'Dark Hair': 157,
#  'Peak Spike': 303,
#  'Cap': 351,
#  'Normal Beard Black': 289,
#  'VR': 332,
#  'Frumpy Hair': 442,
#  'Cigarette': 961,
#  'Normal Beard': 292,
#  'Red Mohawk': 147,
#  'Shaved Head': 300,
#  'Chinstrap': 282,
#  'Mole': 644,
#  'Knitted Cap': 419,
#  'Fedora': 186,
#  'Shadow Beard': 526,
#  'Straight Hair': 151,
#  'Hoodie': 259,
#  'Eye Patch': 461,
#  'Headband': 406,
#  'Cowboy Hat': 142,
#  'Tassle Hat': 178,
#  '3D Glasses': 286,
#  'Mustache': 288,
#  'Vape': 272,
#  'Choker': 48,
#  'Pink With Hat': 95,
#  'Welding Goggles': 86,
#  'Vampire Hair': 147,
#  'Mohawk Thin': 441,
#  'Tiara': 55,
#  'Front Beard Dark': 260,
#  'Cap Forward': 254,
#  'Gold Chain': 169,
#  'Purple Hair': 165,
#  'Beanie': 44,
#  'Clown Hair Green': 148,
#  'Pigtails': 94,
#  'Silver Chain': 156,
#  'Front Beard': 273,
#  'Rosy Cheeks': 128,
#  'Orange Side': 68,
#  'Wild Blonde': 144,
#  'Buck Teeth': 78,
#  'Top Hat': 115,
#  'Medical Mask': 174,
#  'Spots Teeth': 1,
#  'Medical Mask Teeth': 1}
